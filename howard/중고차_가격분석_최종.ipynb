# %% [markdown]
# # 미국 중고차 가격 예측
# - 조대선, 홍성현, 배준영, 유호원

# %% [markdown]
# # 가설
# - 주행거리 5만킬로 미터 이하일때 파는게 좋을것이다.
# - 지역별 가격차이가 있을것이다.
# - 경제위기가 왔을때, 중고차 가격에 영향이 있을것이다.

# %% [markdown]
# # 현재 진행상황
# - 데이터 전처리
# - EDA
# - 모델링

# %% [markdown]
# ## 데이터 출처
# - Craigslist(크레이그리스트) https://craigslist.org/ : 중고 매물, 구인 구직, 주택, 자유 주제 토론등을 다루는 커뮤니티 웹사이트
# - 미국내 중고차 매물 약 51만 건(업데이트 : 2020년 1월)
# - 데이터 출처 : https://www.kaggle.com/austinreese/craigslist-carstrucks-data (캐글)
# - Craigslist Filter 웹 애플리케이션(https://craigslist-filter.herokuapp.com/)
# - 웹 애플리케이션 github : https://github.com/AustinReese/craigslistFilter (github)

# %% [markdown]
# <img src="./img/img2.png" width="1200">

# %% [markdown]
# <img src="./img/img6.png" width="1200">

# %% [markdown]
# #### 슬라이드쇼 할때 raw코드 안보이게 하기

# %%
from IPython.display import HTML

HTML('''
<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>'''
     )
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# #### 표, 마크다운 글씨 크기 조절

# %%
# %%html
# <style>
# table {float:left}
# table td, table th {
#         border-style: solid;
#         font-size: 15px;
# }
# li {
#     font-size: 15px;
#     margin:5px;
# }
# </style>

# %% [markdown]
# ## 컬럼 정보
#
# |컬럼명|내용|설명|
# |:------|:---|:---|
# |<span style= 'background:yellow'> **price** </span> | **entry price** |  **중고차 가격**|
# |<span style= 'background:pink'>**year**</span> | **entry year** | **중고차 연식**|
# |<span style= 'background:#ADD8E6'>**manufacturer**</span> |  **manufacturer of vehicle**| **제조사**|
# |<span style= 'background:#ADD8E6'>**cylinders**</span> |  **number of cylinder** | **엔진 기통수** |
# |<span style= 'background:#ADD8E6'>**fuel**</span> |  **fuel type** | **연료타입** |
# |<span style= 'background:pink'>**odometer**</span> |  **miles traveled by vehicle**| **총주행거리**|
# |<span style= 'background:#ADD8E6'>**title_status**</span> |  **title status of vehicle** |**차량 상태**|
# |<span style= 'background:#ADD8E6'>**transmission**</span> |  **transmission of vehicle**| **미션**|
# |<span style= 'background:'>**vin**</span> |  **vehicle identification numbe**| **차대번호**|
# |<span style= 'background:#ADD8E6'>**drive**</span> |  **type of drive** |**구동방식**|
# |<span style= 'background:#ADD8E6'>**size**</span> |  **size of vehicle** | **차량크기**|
# |<span style= 'background:#ADD8E6'>**type**</span> |  **generic type of vehicle**| **차량 타입**|
# |<span style= 'background:#ADD8E6'>**paint_color**</span> |  **color of vehicle**| **차량 색상**|
# |<span style= 'background:#ADD8E6'>**state**</span> |  **state of listing**| **주 명**|

# %% [markdown]
# ### **예측에 도움이 되지 않는 데이터**
# |컬럼명|내용|설명|
# |:------|:---|:---|
# |lat|  latitude of listing| 위도|
# |long |  longitude of listing| 경도|
# |url |  listing  | 중고차 등록 URL |
# |region |  craigslist region | 중고차 거래 지역|
# |region_url |  region URL | 중고차 지역 정보 URL|
# |image_url |  image URL | 중고차 사진 URL|
# |size |  size of vehicle | 차량 크기, 결측치 50% 이상|
# |condition |  condition of vehicle| 차량 상태, 결측치 45% 이상|
# |description |  listed description of vehicle|  중고차 상태 설명|
# |county |  useless column left in by mistake | 행정 구역 단위 (데이터 없음)|
# |model |  model of vehicle| 차량 모델명, 다른 feature들의 대표성을 띄는 데이터 (다중 공선성 발생)|

# %% [markdown]
# # 데이터 탐색

# %% [markdown]
# ## 전처리

# %%
# 사용되는 패키지
import re
import missingno as msno
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy import stats
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# 컬럼 display 제한 상향
pd.set_option('display.max_columns', 500)

# 지수 표기법 해제
pd.options.display.float_format = '{:.5f}'.format

# %%
raw_data = pd.read_csv("vehicles.csv")

# %%
start_df = raw_data[['id','price','year','odometer','drive','fuel','manufacturer','state','title_status','transmission','type','paint_color','cylinders','vin']]

# %%
start_df.shape
# Out:
# (509577, 14)

# %% [markdown]
# ### 결측치 확인

# %%
msno.matrix(start_df)
plt.show()

# %% [markdown]
# #### 결측치 수치화

# %%
def columns_na_percentage(columns):
    for column in columns:
        percentage = round(100 -(len(raw_data['{}'.format(column)].dropna()) / len(raw_data)) * 100,2)
        if percentage :
            print("{} : ".format(column), percentage,"%",end='\n')

            
columns_na_percentage(start_df.columns)
# Out:
# year :  0.3 %
# odometer :  18.12 %
# drive :  28.29 %
# fuel :  0.78 %
# manufacturer :  4.47 %
# title_status :  0.6 %
# transmission :  0.73 %
# type :  27.77 %
# paint_color :  32.32 %
# cylinders :  39.19 %
# vin :  40.71 %

# %% [markdown]
# #### 결측치 제거

# %%
start_df = start_df.dropna(axis=0)
start_df.shape
# Out:
# (120609, 14)

# %% [markdown]
# ## 차대 번호(vin)를 활용한 데이터 필터링

# %% [markdown]
# ## 전처리전 price  컬럼

# %% [markdown]
# <img src="./img/img7.png" width="1000">

# %% [markdown]
# - **Step1**
#     - 중복된 'vin'을 가지고 있는 데이터 삭제

# %%
vin_non_dup_df = start_df.loc[start_df['vin'].drop_duplicates(keep='last').index]
vin_non_dup_df.shape
# Out:
# (77678, 14)

# %% [markdown]
# - **Step2**
#     - 'vinaudit.com'이 제공하는 api를 이용
#      <img src="./img/img1.png" width="850" style="float:left">

# %% [markdown]
# - **데이터 출처**
#     - 자동차 이력 제공시스템 : (NMVTIS/National Motor Vehicle Title Information System)
#     - 미국 도로교통 안전국 : (NHTSA / National Highway Traffic Safety Administration)
#     - 미국 교통부 연방차량안전국 : (Federal Motor Carrier Safety Administration, FMCSA)
#     - 그외 미국 정부 기관과 관련된 업체 및 파트너사

# %% [markdown]
# ## 크롤링 데이터 분석

# %% [markdown]
# |컬럼명|설명|
# |:------|:---|
# | **above** | 최대 가격|
# |**average** | 평균 가격|
# |**below** | 최소 가격 |
# |**certainty** | 정확도 |
# |**count**|  거래 횟수|
# |**error** |  에러 메세지 |
# |**mileage**|  주행 거리 |
# |**period**|  거래 시기|
# |**stdev**|  표준 편차|
# |**success**|  성공 여부|
# |**vehicle**|  차량 정보 (연식, 제조사, 모델명)|

# %% [markdown]
# <img src="./img/img3.png" width="800">

# %% [markdown]
# - **데이터 사용처**
#     - Vincheck등 중고차 매물 검색 업체
# <img src="./img/img5.png" width="250">
#     - NICB (National Insurance Crime Bureau) 등
# <img src="./img/img4.png" width="200">

# %% [markdown]
# ### 크롤링 데이터를 활용한 데이터 필터링

# %%
vin_crawling_data = pd.read_csv('./final_vin_crawling.csv')

# 대문자 변경
vin_crawling_data['vin'] = vin_crawling_data['vin'].str.upper()

# 중복제거
vin_crawling_data_drop_dupli = vin_crawling_data.drop_duplicates('vin',keep='first')

# 대문자 변경
vin_non_dup_df['vin'] = vin_non_dup_df['vin'].str.upper()

# merge
merged_df = pd.merge(vin_non_dup_df,vin_crawling_data_drop_dupli,on='vin')

# 중복 제거
merged_df = merged_df.drop_duplicates('vin',keep='first')

# 필요 없는 컬럼 제거
df = merged_df[merged_df.columns.difference(['id_y','Unnamed: 0','Unnamed: 0.1','og_vin'])]
df.shape
# Out:
# (77569, 26)

# %%
msno.matrix(df)
plt.show()

# %% [markdown]
# ### error 컬럼
# - 'no_data' : request시에 던져준 'odometer'가 잘못되어 정보를 가져올수 없는 경우, 즉 이력조회가 되지않는 차량
# - 'invalid_vin' : request시에 던져준 'vin'이 17자리가 아닌 경우
#   - 1980년도 이전에 생산된 차량의 정보는 데이터베이스화 되어있지 않음
#   - 판매자가 잘못된 vin값을 입력한 경우

# %%
df['error'].value_counts()
# Out:
# no_data        4263
# invalid_vin    3038
# Name: error, dtype: int64

# %% [markdown]
# - 'error'값을 가지고 있는 row들을 제거

# %%
df=df[df.columns.difference(['error'])]

# %%
df = df.dropna(axis=0)
msno.matrix(df)
plt.show()

# %% [markdown]
# # 아웃라이어 탐색

# %% [markdown]
# ### 가격 아웃라이어 탐색

# %% [markdown]
# - 평균가격과 표준편차를 이용해 'price'의 아웃라이어를 필터링

# %%
df[['above', 'average', 'below','stdev']].head(2)
# Out:
#         above     average       below      stdev
# 0 20878.90000 18399.90000 15920.90000 2479.00000
# 1  8113.75000  6710.75000  5307.75000 1403.00000

# %% [markdown]
# ### 평균값과 표준편차를 이용한 데이터 필터링

# %%
def get_sigma_data_by_price(num):
    # price가 0인것들 제거
    sigma = df[(df['price'] >= (df['average'] - (df['stdev']*num))) & (df['price'] <= (df['average'] + (df['stdev']*num)))]
    print("{} sigma data : ".format(num),sigma.shape)
    return sigma

sigma_2_df = get_sigma_data_by_price(2)
sigma_2_df.shape
# Out:
# 2 sigma data :  (56026, 25)
# (56026, 25)

# %%
# year를 int로 형변환
sigma_2_df['year'] = sigma_2_df['year'].astype('int')

# %% [markdown]
# ### 주행거리 아웃라이어 탐색
# - odometer와 mileage가 다른 데이터 : 판매자가 과도하게 높은 odometer를 입력한 경우

# %%
print("주행거리가 잘못 입력된 차량 대수 : ",len(sigma_2_df[sigma_2_df['mileage'] != sigma_2_df['odometer']]))
sigma_2_df[sigma_2_df['mileage'] != sigma_2_df['odometer']].sort_values(ascending=False,by='odometer').head(2)
# Out:
# 주행거리가 잘못 입력된 차량 대수 :  31
#             above    average      below  certainty   count    cylinders drive  \
# 51426 10244.99000 8898.99000 7552.99000   81.70000 9.00000  6 cylinders   4wd
# 8407   5276.60000 4335.60000 3394.60000   65.00000 4.00000  8 cylinders   4wd
#
#       fuel        id_x manufacturer       mean      mileage      odometer  \
# 51426  gas  7046006501        lexus 8898.99000 148490.00000 4706000.00000
# 8407   gas  7034479993        dodge 4335.60000 180265.00000 4000085.00000
#
#       paint_color                        period  price state      stdev  \
# 51426      custom  ['2019-10-02', '2020-03-07']   8000    nc 1346.00000
# 8407       custom  ['2019-10-05', '2020-01-15']   3995    al  941.00000
#
#       success title_status transmission type                  vehicle  \
# 51426    True        clean    automatic  SUV  2007 Lexus RX 400h Base
# 8407     True        clean    automatic  SUV   2004 Dodge Durango SLT
#
#                      vin  year
# 51426  JTJHW31UX72010051  2007
# 8407   1D4HB48N44F169643  2004

# %%
# 주행거리 아웃라이어 제거
sigma_2_df = sigma_2_df[sigma_2_df['mileage'] == sigma_2_df['odometer']]

# %% [markdown]
# ### 박스플롯, 스캐터 플롯

# %%
plt.figure(figsize=(16,12))
plt.subplot(211)
sns.boxplot(x="year", y="price", data = sigma_2_df)
plt.xticks(rotation=90)
plt.subplot(212)
sns.scatterplot(sigma_2_df['year'],sigma_2_df['odometer'])
# plt.subplot(313)
# sns.scatterplot(test2['year'],test2['price'])

plt.show()

# %% [markdown]
# ## 플롯 그린후 눈으로 본 데이터

# %% [markdown]
# - 연도

# %%
# year 수정해 줘야 하는 데이터
sigma_2_df[sigma_2_df['year'] < 1980]
# Out:
#             above     average       below  certainty     count    cylinders  \
# 49431 31752.09000 28691.09000 25630.09000   99.00000 240.00000  8 cylinders
#
#       drive fuel        id_x manufacturer        mean     mileage    odometer  \
# 49431   rwd  gas  7035287698      pontiac 28691.09000 36211.00000 36211.00000
#
#       paint_color                        period  price state      stdev  \
# 49431        blue  ['2019-12-14', '2020-03-26']  27988    mt 3061.00000
#
#       success title_status transmission   type              vehicle  \
# 49431    True        clean    automatic  other  2019 Toyota Sienna
#
#                      vin  year
# 49431  5TDYZ3DC0KS008940  1968

# %%
sigma_2_df['year'] = sigma_2_df['year'].apply(lambda x : 2019 if x < 1980 else x)

# %% [markdown]
# - 주행거리

# %%
sigma_2_df[sigma_2_df['odometer'] > 500000]
# Out:
#            above    average      below  certainty   count    cylinders drive  \
# 28776 9045.70000 6984.70000 4923.70000   65.00000 4.00000  8 cylinders   4wd
#
#       fuel        id_x manufacturer       mean      mileage     odometer  \
# 28776  gas  7044009302       toyota 6984.70000 533000.00000 533000.00000
#
#       paint_color                        period  price state      stdev  \
# 28776        grey  ['2019-10-03', '2020-02-20']   6500    ga 2061.00000
#
#       success title_status transmission type                        vehicle  \
# 28776    True        clean    automatic  SUV  2002 Toyota Land Cruiser Base
#
#                      vin  year
# 28776  JTEHT05J722017912  2002

# %%
# 약 18년간 운행한 자동차의 일 평균 주행거리 계산
print("평균 주행거리 : ", round(533000.00 / (365* 18),2),"마일/day")
# Out:
# 평균 주행거리 :  81.13 마일/day

# %% [markdown]
# - 가격
#   - 75000불 초과 차량 확인

# %%
sigma_2_df[sigma_2_df['price'] > 75000].sort_values(by=['price'],ascending=False).head()
# Out:
#              above      average        below  certainty    count  \
# 60128 202032.56000 182660.56000 163288.56000   90.00000 16.00000
# 29627 149400.58000 132238.58000 115076.58000   70.30000  5.00000
# 20351 130595.38000 124912.38000 119229.38000   79.60000  8.00000
# 10976 125445.67000 119893.67000 114341.67000   74.20000  6.00000
# 73531 117293.94000 105051.94000  92809.94000   90.70000 17.00000
#
#           cylinders drive    fuel        id_x   manufacturer         mean  \
# 60128   8 cylinders   4wd     gas  7045671330  mercedes-benz 182660.56000
# 29627   3 cylinders   4wd  hybrid  7048009986            bmw 132238.58000
# 20351  10 cylinders   4wd     gas  7049707044           audi 124912.38000
# 10976   8 cylinders   rwd     gas  7043599850        ferrari 119893.67000
# 73531   8 cylinders   rwd     gas  7047378977  mercedes-benz 105051.94000
#
#           mileage    odometer paint_color                        period  \
# 60128  7584.00000  7584.00000       white  ['2019-10-03', '2020-03-26']
# 29627   649.00000   649.00000        grey  ['2019-10-05', '2020-03-14']
# 20351 25624.00000 25624.00000         red  ['2019-10-06', '2020-03-19']
# 10976 12986.00000 12986.00000       black  ['2019-10-03', '2020-03-22']
# 73531  5560.00000  5560.00000       black  ['2019-10-01', '2020-03-26']
#
#         price state       stdev success title_status transmission  \
# 60128  193982    oh 19372.00000    True        clean    automatic
# 29627  139995    hi 17162.00000    True        clean    automatic
# 20351  121995    co  5683.00000    True        clean    automatic
# 10976  114950    az  5552.00000    True        clean    automatic
# 73531  109995    tx 12242.00000    True        clean    automatic
#
#               type                         vehicle                vin  year
# 60128          SUV            2019 Mercedes-Benz    WDCYC7HJ3KX301396  2019
# 29627  convertible                      2019 BMW    WBY2Z6C52KVB82784  2019
# 20351        coupe      2017 Audi R8 (V10 quattro)  WUAEAAFX4H7901309  2017
# 10976  convertible    2014 Ferrari California Base  ZFF65TJAXE0200770  2014
# 73531  convertible  2018 Mercedes-Benz AMG GT Base  WDDYK7HA6JA014263  2018

# %% [markdown]
# - 500불 미만 차량 확인

# %%
sigma_2_df[sigma_2_df['price'] < 500].sort_values(by=['price'],ascending=False)
# Out:
#             above     average      below  certainty   count    cylinders  \
# 22916  1708.69000  1139.69000  570.69000   57.30000 3.00000  4 cylinders
# 39176   280.57000   242.57000  204.57000   44.30000 2.00000  8 cylinders
# 38722 18636.20000 12424.20000 6212.20000   44.30000 2.00000  8 cylinders
# 38633 11662.95000  7775.95000 3888.95000   44.30000 2.00000  8 cylinders
# 24512  4792.78000  3195.78000 1598.78000   44.30000 2.00000  6 cylinders
#
#       drive   fuel        id_x manufacturer        mean      mileage  \
# 22916   4wd    gas  7037527384        honda  1139.69000 380774.00000
# 39176   fwd    gas  7040987260      lincoln   242.57000 180000.00000
# 38722   rwd  other  7037057151    chevrolet 12424.20000 158389.00000
# 38633   rwd  other  7040079832    chevrolet  7775.95000 220790.00000
# 24512   fwd    gas  7041931251         ford  3195.78000 146221.00000
#
#           odometer paint_color                        period  price state  \
# 22916 380774.00000      silver  ['2020-02-21', '2020-03-11']    390    de
# 39176 180000.00000         red  ['2019-11-01', '2019-12-04']    300    la
# 38722 158389.00000       white  ['2019-10-10', '2019-10-10']    150    ky
# 38633 220790.00000       white  ['2019-10-10', '2019-10-10']    131    ky
# 24512 146221.00000       white  ['2019-10-08', '2019-10-15']     85    fl
#
#            stdev success title_status transmission   type  \
# 22916  569.00000    True        clean    automatic  sedan
# 39176   38.00000    True        clean    automatic  sedan
# 38722 6212.00000    True        clean    automatic    van
# 38633 3887.00000    True        clean    automatic    van
# 24512 1597.00000    True        clean    automatic    SUV
#
#                                  vehicle                vin  year
# 22916                2005 Honda Civic LX  2HGES16695H615734  2005
# 39176      1999 Lincoln Continental Base  1LNHM97V3XY629191  1999
# 38722  2012 Chevrolet Express Cargo 2500  1GCWGFBA7C1155304  2012
# 38633  2012 Chevrolet Express Cargo 2500  1GCWGFBA8C1126880  2012
# 24512               2005 Ford Escape XLT  1FMCU03115KA47874  2005

# %%
# 이상치 가격을 보이는 차량 제거
sigma_2_df = sigma_2_df[(sigma_2_df['vin'] != '1GCWGFBA7C1155304') & (sigma_2_df['vin'] != '1GCWGFBA8C1126880') & (sigma_2_df['vin'] != '1FMCU03115KA47874')]

# %% [markdown]
# ### 0값 제거
# - price, odometer 값이 0인 경우 제거

# %%
print("판매자가 주행거리를 0으로 올려둔 경우 : ",len(sigma_2_df[sigma_2_df['odometer'] == 0]),"건")
sigma_2_df[sigma_2_df['odometer'] == 0].head(2)
sigma_2_df= sigma_2_df[sigma_2_df['odometer'] != 0]
# Out:
# 판매자가 주행거리를 0으로 올려둔 경우 :  50 건

# %%
# vinaudit에서 가격을 예측 했으나, 판매자가 가격을 매기지 않고 0이라고 올려둔 경우
print("판매자가 가격을 매기지 않고 0이라고 올려둔 경우 : ",len(sigma_2_df[sigma_2_df['price'] == 0]),"건")
sigma_2_df[sigma_2_df['price'] == 0].head(2)
sigma_2_df= sigma_2_df[sigma_2_df['price'] != 0]
# Out:
# 판매자가 가격을 매기지 않고 0이라고 올려둔 경우 :  0 건

# %% [markdown]
# ### column 정리
# - 분석에 필요한 컬럼

# %%
df = sigma_2_df[['price','year','odometer','drive','fuel','manufacturer','state','title_status','transmission','type','paint_color','cylinders']]
sigma_2_df.shape
# Out:
# (55942, 25)

# %%
sigma_2_df.shape
# Out:
# (55942, 25)

# %%
raw_data_non_dup = raw_data.drop_duplicates('vin')

# %%
test = sigma_2_df.merge(raw_data_non_dup[['vin','condition']],on='vin',how='left')

# %%
df = test[['price','year','odometer','drive','fuel','manufacturer','state','title_status','transmission','type','paint_color','cylinders','condition']]

# %%
test['condition'].unique()
# Out:
# array(['excellent', 'good', nan, 'like new', 'new', 'fair', 'salvage'],
#       dtype=object)

# %%
test['condition'] = test['condition'].fillna('other')

# %%
msno.matrix(test)

# %%
df = df.reset_index(drop=True)

# %%
msno.matrix(df)
plt.show()

# %% [markdown]
# ### 카테고리 데이터 빈도수에 따른 필터링

# %%
def value_counts_filter(num, columns):
    for column in columns:
        result = df[column].value_counts()[df[column].value_counts().sort_values() < num]
        if len(result) !=0:
            print(result,end="\n\n===========\n\n")

# %% [markdown]
# # 데이터가 각각 나눠서 들어갈수 있게 함수 짜야 한다

# %%
def check_under_10_index(start_num,end_num,columns,df):
    test = {}
    test2 = []
    for column in columns:
        len_under_10 = len(df[column].value_counts()[(df[column].value_counts() < end_num) & (df[column].value_counts() > start_num)])
        if len_under_10:
            for i in range(len_under_10):
                index = df[df[column] == df[column].value_counts()[(df[column].value_counts() < end_num) & (df[column].value_counts() > start_num)].index[i]].index.values
                value = df[column].value_counts()[(df[column].value_counts() < end_num) & (df[column].value_counts() > start_num)].index[i]  
                test[value] = index
    test2.append(test)
    return test2

# %%
test = check_under_10_index(2,10, df[['cylinders','manufacturer','title_status','type']],df)
test_df = pd.DataFrame(test)
test_df
# Out:
#                                                tesla  \
# 0  [1037, 1897, 12701, 12713, 13567, 13568, 15060...
#
#                                          alfa-romeo  \
# 0  [1931, 11481, 13715, 18035, 29591, 49763, 51630]
#
#                harley-davidson                       missing  \
# 0  [7006, 34363, 52348, 52376]  [10963, 16194, 20106, 33971]
#
#             parts only                          bus
# 0  [9401, 9961, 29878]  [1336, 10320, 16975, 27573]

# %%
value_counts_filter(10,df.columns.difference(['price','odometer','year']))
# Out:
# 12 cylinders    2
# Name: cylinders, dtype: int64
#
# ===========
#
# tesla              9
# alfa-romeo         7
# harley-davidson    4
# porche             2
# land rover         2
# aston-martin       1
# ferrari            1
# Name: manufacturer, dtype: int64
#
# ===========
#
# missing       4
# parts only    3
# Name: title_status, dtype: int64
#
# ===========
#
# bus    4
# Name: type, dtype: int64
#
# ===========

# %%
def delete_under_ten():
    
    result = df[df['cylinders'] != '12 cylinders']
    
    result = result[result['type'] != 'bus']
    
    result = result[(result['title_status'] != 'parts only') & (result['title_status'] != 'missing')]
    
    result = result[(result['manufacturer'] != 'ferrari') & (result['manufacturer'] != 'porche') & (result['manufacturer'] != 'land rover') & (result['manufacturer'] != 'harley-davidson') ]
    
    result = result[(result['manufacturer'] != 'tesla')]
    
    result = result[(result['manufacturer'] != 'alfa-romeo') & (result['manufacturer'] != "aston-martin") ]
    return result

# %% [markdown]
# ## 변수탐색

# %% [markdown]
# ### 종속변수 - 가격(price)

# %%
df.price.sort_values(ascending=False)[:20]
# Out:
# 63406    193982
# 63405    193982
# 30165    139995
# 30166    139995
# 21473    121995
# 12633    114950
# 80632    109995
# 15372    103999
# 65434     92991
# 65433     92991
# 30446     89995
# 16873     89800
# 65241     82991
# 30116     80905
# 30115     80905
# 85606     79997
# 85601     79997
# 85596     79997
# 85597     79997
# 85598     79997
# Name: price, dtype: int64

# %%
plt.figure(figsize=(17,6))

plt.subplot(131)
sns.distplot(np.log(df['price']))

plt.subplot(132)
sns.boxplot(np.log(df['price']))

plt.subplot(133)
stats.probplot(np.log(df['price']),plot=plt)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 독립변수

# %% [markdown]
# ### 연식

# %%
plt.figure(figsize=(16,8))
sns.countplot(
    df['year']
)
plt.title("차량 제조연도")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 주행거리

# %%
plt.figure(figsize=(16,7))
plt.subplot(121)
sns.distplot(df['odometer'])
plt.subplot(122)
sns.distplot(df['odometer'])
plt.tight_layout()
plt.xlim(0,250000)
plt.show()

# %% [markdown]
# ### 카테고리 독립변수 확인

# %%
plt.figure(figsize=(15,20))
plt.subplot(621)
sns.countplot(
    data = df,
    y = "fuel",
    palette='Set1',
)
plt.title("연료 타입별")


plt.subplot(622)
sns.countplot(
    data = df,
    y = "cylinders",
    palette='Set1',
    order = df['cylinders'].value_counts().index

)
plt.title("실린더 종류별")


plt.subplot(623)
sns.countplot(
    data = df,
    y = "transmission",
    palette='Set1'
)
plt.title("변속기")

plt.subplot(624)
sns.countplot(
    data = df,
    y = "drive",
    palette='Set1'
)
plt.title("구동 방식")


plt.subplot(625)
sns.countplot(
    data = df,
    y = "title_status",
    palette='Set1'
)
plt.title("차량 상태별")


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18,10))

plt.subplot(221)
sns.countplot(
    data = df,
    y = "type",
    palette='Set1',
    order = df['type'].value_counts().index
)
plt.title("차량 종류별")


plt.subplot(222)
sns.countplot(
    data = df,
    y = "paint_color",
    palette='Set1',
    order = df['paint_color'].value_counts().index

)
plt.title("차량 색깔별")

plt.subplot(223)
sns.countplot(
    data = df,
    y = "manufacturer",
    palette='Set1',
    order = df['manufacturer'].value_counts().iloc[:7].index,

)
plt.title("제조사별")

plt.subplot(224)
sns.countplot(
    data = df,
    y = "state",
    palette='Set1',
    order = df['state'].value_counts().iloc[:7].index
)
plt.title("주 별")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  변수 상관분석

# %%
sns.pairplot(df[['price','odometer','year']],size=3)
plt.show()

# %%
fig = plt.figure(figsize=(20,8))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)


others = list(set(df.columns).difference(set(["price", "odometer"])))
p, resids = sm.graphics.plot_partregress(
    "price", "odometer", others, data=df, obs_labels=False, ret_coords=True, ax = ax1
)


others2 = list(set(df.columns).difference(set(["price", "year"])))
p, resids = sm.graphics.plot_partregress(
    "price", "year", others2, data=df, obs_labels=False, ret_coords=True, ax = ax2
)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Train, Test 데이터 분할
# - Train, Test 데이터 분할 및 k-fold 데이터 분할을 위한 카테고리 데이터 정리

# %% [markdown]
# ### 카테고리 데이터 빈도수에 따른 필터링

# %%
def value_counts_filter(num, columns):
    for column in columns:
        result = df[column].value_counts()[df[column].value_counts().sort_values() < num]
        if len(result) !=0:
            print(result,end="\n\n===========\n\n")

# %%
value_counts_filter(10,df.columns.difference(['price','odometer','year']))
# Out:
# 12 cylinders    2
# Name: cylinders, dtype: int64
#
# ===========
#
# tesla              9
# alfa-romeo         7
# harley-davidson    4
# porche             2
# land rover         2
# aston-martin       1
# ferrari            1
# Name: manufacturer, dtype: int64
#
# ===========
#
# missing       4
# parts only    3
# Name: title_status, dtype: int64
#
# ===========
#
# bus    4
# Name: type, dtype: int64
#
# ===========

# %% [markdown]
# ### 2개 초과 10개 미만 데이터 인덱스 확인

# %%
def check_under_10_index(start_num,end_num,columns,df):
    test = {}
    test2 = []
    for column in columns:
        len_under_10 = len(df[column].value_counts()[(df[column].value_counts() < end_num) & (df[column].value_counts() > start_num)])
        if len_under_10:
            for i in range(len_under_10):
                index = df[df[column] == df[column].value_counts()[(df[column].value_counts() < end_num) & (df[column].value_counts() > start_num)].index[i]].index.values
                value = df[column].value_counts()[(df[column].value_counts() < end_num) & (df[column].value_counts() > start_num)].index[i]  
                test[value] = index
    test2.append(test)
    return test2

# %%
index_dict = check_under_10_index(2,10, df[['cylinders','manufacturer','title_status','type']],df)
index_df = pd.DataFrame(index_dict)
index_df
# Out:
#                                                tesla  \
# 0  [1037, 1897, 12701, 12713, 13567, 13568, 15060...
#
#                                          alfa-romeo  \
# 0  [1931, 11481, 13715, 18035, 29591, 49763, 51630]
#
#                harley-davidson                       missing  \
# 0  [7006, 34363, 52348, 52376]  [10963, 16194, 20106, 33971]
#
#             parts only                          bus
# 0  [9401, 9961, 29878]  [1336, 10320, 16975, 27573]

# %%
for_test_data = []
for_train_data_train = []
for_train_data_test = []
for column in index_df.columns:
    start = list(index_df[column][0])
    random.shuffle(start)
    if len(start) > 4:
        m = [start[i:i + 3] for i in range(0, len(start), 3)]
        for_test_data.append(m[0])
        for_train_data_train.append(m[1])
        for_train_data_test.append(m[2])
    elif len(start) == 4:
        m = [start[:2], start[2:3], start[3:]]
        for_test_data.append(m[0])
        for_train_data_train.append(m[1])
        for_train_data_test.append(m[2])
    else :
        m = [[i] for i in start]
        for_test_data.append(m[0])
        for_train_data_train.append(m[1])
        for_train_data_test.append(m[2])

# %%
len(for_test_data), len(for_train_data_train), len(for_train_data_test)
# Out:
# (6, 6, 6)

# %% [markdown]
# ### 데이터 분할에 사용할 인덱스 분류

# %%
for_test_data = []
for_train_data_train = []
for_train_data_test = []
for column in ['tesla','alfa-romeo','harley-davidson','missing','bus','parts only']:
    start = list(index_df[column][0])
    random.shuffle(start)
    if len(start) > 4:
        m = [start[i:i + 3] for i in range(0, len(start), 3)]
        for_test_data.append(m[0])
        for_train_data_train.append(m[1])
        for_train_data_test.append(m[2])
    elif len(start) == 4:
        m = [start[:2], start[2:3], start[3:]]
        for_test_data.append(m[0])
        for_train_data_train.append(m[1])
        for_train_data_test.append(m[2])
    else :
        m = [[i] for i in start]
        for_test_data.append(m[0])
        for_train_data_train.append(m[1])
        for_train_data_test.append(m[2])

# %% [markdown]
# ### 10개 미만 데이터 우선 삭제

# %%
index_df.columns
# Out:
# Index(['tesla', 'alfa-romeo', 'harley-davidson', 'missing', 'parts only',
#        'bus'],
#       dtype='object')

# %%
def delete_under_ten():
    
    result = df[df['cylinders'] != '12 cylinders']
    
    result = result[result['type'] != 'bus']
    
    result = result[(result['title_status'] != 'parts only') & (result['title_status'] != 'missing')]
    
    result = result[(result['manufacturer'] != 'ferrari') & (result['manufacturer'] != 'porche') & (result['manufacturer'] != 'land rover') & (result['manufacturer'] != 'harley-davidson') ]
    
    result = result[(result['manufacturer'] != 'tesla')]
    
    result = result[(result['manufacturer'] != 'alfa-romeo') & (result['manufacturer'] != "aston-martin") ]
    return result

# %%
df_deleted_under_ten = delete_under_ten()

# %%
df.shape
# Out:
# (55942, 12)

# %%
df_deleted_under_ten.shape
# Out:
# (55903, 12)

# %% [markdown]
# # 데이터 분할
# - train용 데이터 : 80%
# - test용 데이터 : 20%

# %%
train_data, test_data = train_test_split(df_deleted_under_ten, test_size = .20, random_state = 7)
train_data = pd.concat([train_data, df.iloc[
    [element for array in for_train_data_train for element in array] + [element for array in for_train_data_test for element in array]
]],axis=0)
test_data = pd.concat([test_data,df.iloc[
    [element for array in for_test_data for element in array]]])
train_data.shape, test_data.shape
# Out:
# ((44740, 12), (11194, 12))

# %%
len(train_data) +  len(test_data)
# Out:
# 55934

# %% [markdown]
# # 모델

# %%
msno.matrix(train_data)
plt.show()

# %% [markdown]
# ### LinearRegression
# - train, test 데이터 분류
# - test size : 0.2
# - 종속변수인 가격에 log를 씌움

# %%
X = train_data[train_data.columns.difference(['id_x','model','vin','price'])]
Y = np.log(train_data['price'])
X = pd.get_dummies(data=X, drop_first=True)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .20, random_state = 0)

test_df = pd.concat([Y_train,X_train],axis=1)

model = linear_model.LinearRegression() 
result = model.fit(X_train, Y_train)
predicted = result.predict(X_test)
print('Test R2 score : ',r2_score(Y_test,predicted))
plt.scatter(Y_test,predicted)


pred_tr = result.predict(X_train)
pred_test = result.predict(X_test)
rmse_tr = (np.sqrt(mean_squared_error(Y_train, pred_tr)))
rmse_test = (np.sqrt(mean_squared_error(Y_test, pred_test)))


# cv = KFold(10, shuffle=True, random_state=0)
model_0_cross_val_score= cross_val_score(model, X, Y, scoring=None, cv=10)

print('RMSE of Train Data : ', rmse_tr)
print('RMSE of Test Data : ', rmse_test)
print('K-fold : ',model_0_cross_val_score)
# Out:
# Test R2 score :  0.8570754046056238
# RMSE of Train Data :  0.25794931421549094
# RMSE of Test Data :  0.2568869218052052
# K-fold :  [0.84953741 0.86064068 0.85288496 0.85969624 0.86023538 0.8534778
#  0.85884077 0.85467308 0.85484546 0.85436916]

# %% [markdown]
# ### sm.OLS.from_formula
# - train, test 데이터 분류
# - test size : 0.2
# - 종속변수인 가격에 log를 씌움

# %% [markdown]
# ### Model 1
# - ```"price ~ scale(odometer) + scale(year) + cylinders + drive + fuel + manufacturer + paint_color + state + title_status + transmission + type"```

# %%
X = train_data[train_data.columns.difference(['price'])]
Y = train_data['price']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .20,random_state=0)

test_df = pd.concat([Y_train,X_train],axis=1)


model1 = sm.OLS.from_formula("np.log(price) ~ scale(odometer) + scale(year) +{}".format("+".join(test_df.columns.difference(['price','odometer','year'])))+"+0",test_df)
result = model1.fit()


prediction = result.predict(X_test)
print("R2 score : ",r2_score(np.log(Y_test), prediction))
print(result.summary())
# Out:
# R2 score :  0.8570754046056486
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     1657.
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):               0.00
# Time:                        20:22:20   Log-Likelihood:                -2288.8
# No. Observations:               35792   AIC:                             4838.
# Df Residuals:                   35662   BIC:                             5941.
# Df Model:                         129
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# cylinders[10 cylinders]            10.7515      0.039    278.369      0.000      10.676      10.827
# cylinders[3 cylinders]              9.8974      0.040    246.948      0.000       9.819       9.976
# cylinders[4 cylinders]             10.0852      0.020    509.060      0.000      10.046      10.124
# cylinders[5 cylinders]             10.1476      0.027    372.344      0.000      10.094      10.201
# cylinders[6 cylinders]             10.2942      0.019    529.350      0.000      10.256      10.332
# cylinders[8 cylinders]             10.5333      0.020    531.898      0.000      10.494      10.572
# cylinders[other]                   10.0985      0.033    308.237      0.000      10.034      10.163
# drive[T.fwd]                       -0.2561      0.005    -51.866      0.000      -0.266      -0.246
# drive[T.rwd]                       -0.1191      0.005    -23.759      0.000      -0.129      -0.109
# fuel[T.electric]                   -0.5288      0.063     -8.420      0.000      -0.652      -0.406
# fuel[T.gas]                        -0.5383      0.007    -81.562      0.000      -0.551      -0.525
# fuel[T.hybrid]                     -0.4485      0.014    -32.055      0.000      -0.476      -0.421
# fuel[T.other]                      -0.5214      0.014    -38.350      0.000      -0.548      -0.495
# manufacturer[T.alfa-romeo]          0.0898      0.130      0.690      0.490      -0.165       0.345
# manufacturer[T.audi]               -0.0541      0.019     -2.860      0.004      -0.091      -0.017
# manufacturer[T.bmw]                -0.0970      0.016     -5.941      0.000      -0.129      -0.065
# manufacturer[T.buick]              -0.2012      0.019    -10.727      0.000      -0.238      -0.164
# manufacturer[T.cadillac]           -0.0968      0.018     -5.356      0.000      -0.132      -0.061
# manufacturer[T.chevrolet]          -0.2202      0.015    -14.898      0.000      -0.249      -0.191
# manufacturer[T.chrysler]           -0.3176      0.017    -18.245      0.000      -0.352      -0.283
# manufacturer[T.dodge]              -0.3252      0.016    -20.347      0.000      -0.357      -0.294
# manufacturer[T.fiat]               -0.6193      0.033    -18.918      0.000      -0.683      -0.555
# manufacturer[T.ford]               -0.2461      0.015    -16.742      0.000      -0.275      -0.217
# manufacturer[T.gmc]                -0.1623      0.016    -10.178      0.000      -0.194      -0.131
# manufacturer[T.harley-davidson]     0.0433      0.184      0.236      0.814      -0.317       0.403
# manufacturer[T.honda]              -0.0454      0.015     -2.970      0.003      -0.075      -0.015
# state[T.wa]                        -0.0372      0.014     -2.720      0.007      -0.064      -0.010
# state[T.wi]                        -0.0450      0.013     -3.432      0.001      -0.071      -0.019
# state[T.wv]                        -0.1490      0.052     -2.867      0.004      -0.251      -0.047
# state[T.wy]                         0.0893      0.064      1.402      0.161      -0.036       0.214
# title_status[T.lien]                0.0316      0.015      2.106      0.035       0.002       0.061
# title_status[T.missing]            -0.5098      0.183     -2.786      0.005      -0.869      -0.151
# title_status[T.parts only]         -0.2415      0.259     -0.933      0.351      -0.749       0.266
# title_status[T.rebuilt]            -0.1473      0.012    -12.613      0.000      -0.170      -0.124
# title_status[T.salvage]            -0.2114      0.019    -10.975      0.000      -0.249      -0.174
# transmission[T.manual]              0.1199      0.007     17.346      0.000       0.106       0.133
# transmission[T.other]               0.0418      0.008      5.226      0.000       0.026       0.057
# type[T.bus]                        -0.2622      0.184     -1.428      0.153      -0.622       0.098
# type[T.convertible]                 0.1729      0.011     15.158      0.000       0.151       0.195
# type[T.coupe]                       0.0401      0.008      5.086      0.000       0.025       0.055
# type[T.hatchback]                  -0.1510      0.009    -16.882      0.000      -0.169      -0.133
# type[T.mini-van]                   -0.0777      0.011     -7.296      0.000      -0.099      -0.057
# type[T.offroad]                     0.2413      0.036      6.716      0.000       0.171       0.312
# type[T.other]                       0.0084      0.012      0.730      0.465      -0.014       0.031
# type[T.pickup]                      0.1459      0.006     22.706      0.000       0.133       0.158
# type[T.sedan]                      -0.1346      0.005    -29.607      0.000      -0.144      -0.126
# type[T.truck]                       0.1360      0.006     24.005      0.000       0.125       0.147
# type[T.van]                        -0.0306      0.009     -3.260      0.001      -0.049      -0.012
# type[T.wagon]                      -0.0630      0.010     -6.491      0.000      -0.082      -0.044
# scale(odometer)                    -0.2577      0.002   -128.906      0.000      -0.262      -0.254
# scale(year)                         0.3356      0.002    163.480      0.000       0.332       0.340
# ==============================================================================
# Omnibus:                     2502.183   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13173.921
# Skew:                          -0.012   Prob(JB):                         0.00
# Kurtosis:                       5.972   Cond. No.                         255.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### 교차 검증 : k-fold  검증

# %%
kf = KFold(10, shuffle=True, random_state=0)
model_1_cross_val_score = []
for X_train_index, X_test_index in kf.split(train_data):
    
    X_train= train_data.iloc[X_train_index]
    X_test = train_data.iloc[X_test_index]
    
    X_train = pd.concat([X_train, train_data[train_data.index.isin([element for array in for_train_data_train for element in array])]], axis=0)
    X_test = pd.concat([X_test, train_data[train_data.index.isin([element for array in for_train_data_test for element in array])]], axis=0)
    model1 = sm.OLS.from_formula("np.log(price) ~ scale(odometer) + scale(year) +{}".format("+".join(train_data.columns.difference(['price','odometer','year'])))+"+0",X_train)
    result = model1.fit()
    pred = result.predict(X_test)
    model_1_cross_val_score.append(r2_score(np.log(X_test.price),pred))
model_1_cross_val_score
# Out:
# [0.8531612739648569,
#  0.8632147230956942,
#  0.8667150523209048,
#  0.85304501575287,
#  0.8492420768541539,
#  0.8546829670398488,
#  0.8537077836296976,
#  0.8564089341212059,
#  0.8632031131630173,
#  0.8563268202560176]

# %% [markdown]
# ### Model 1
# - ```"price ~ scale(odometer) + scale(year) + cylinders + drive + fuel + manufacturer + paint_color + state + title_status + transmission + type"```
#
# ### Model 2
# - ```"price ~ scale(odometer) + scale(year) + cylinders + drive + fuel + manufacturer + paint_color + state + title_status + transmission + type + scale(year):C(cylinders) + scale(odometer): C(fuel) + scale(year):C(fuel) + scale(odometer): C(drive) + scale(year):C(drive)"```

# %% [markdown]
# # ANOVA를 통한 독립변수 점검

# %%
anova = sm.stats.anova_lm(result, typ=2)
anova.sort_values(by=['F'],ascending=False)
# Out:
#                      sum_sq          df           F  PR(>F)
# cylinders       20996.17838     7.00000 45175.28667 0.00000
# scale(year)      2068.12246     1.00000 31148.34348 0.00000
# scale(odometer)  1199.44924     1.00000 18065.10859 0.00000
# fuel              493.15406     4.00000  1856.86926 0.00000
# drive             194.38630     2.00000  1463.84257 0.00000
# type              203.93113    12.00000   255.95345 0.00000
# manufacturer      450.91292    35.00000   194.03646 0.00000
# transmission       22.34190     2.00000   168.24754 0.00000
# title_status       23.23428     5.00000    69.98707 0.00000
# state              96.45711    50.00000    29.05514 0.00000
# paint_color        11.46689    11.00000    15.70043 0.00000
# Residual         2665.53001 40146.00000         nan     nan

# %% [markdown]
# ### sm.OLS.from_formula
# - train, test 데이터 분류
# - test size : 0.2
# - 종속변수인 가격에 log를 씌움

# %%
X = train_data[train_data.columns.difference(['price'])]
Y = train_data['price']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .20,random_state=0)

test_df = pd.concat([Y_train,X_train],axis=1)

model2 = sm.OLS.from_formula("np.log(price) ~ scale(odometer) + scale(year) + scale(odometer): C(cylinders)+ scale(year):C(cylinders)+{}".format("+".join(df.columns.difference(['price','odometer','year'])))+"+0",test_df)
result = model2.fit()
pred = result.predict(X_test)

print("R2 score : ",r2_score(np.log(Y_test),pred))
print(result.summary())
# Out:
# R2 score :  0.8606443265673106
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(price)   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     1561.
# Date:                Mon, 06 Apr 2020   Prob (F-statistic):               0.00
# Time:                        20:22:47   Log-Likelihood:                -1835.3
# No. Observations:               35792   AIC:                             3955.
# Df Residuals:                   35650   BIC:                             5159.
# Df Model:                         141
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# cylinders[10 cylinders]                        10.6914      0.042    253.314      0.000      10.609      10.774
# cylinders[3 cylinders]                          9.9219      0.090    110.828      0.000       9.746      10.097
# cylinders[4 cylinders]                         10.0843      0.020    514.306      0.000      10.046      10.123
# cylinders[5 cylinders]                         10.1783      0.030    340.085      0.000      10.120      10.237
# cylinders[6 cylinders]                         10.2993      0.019    535.684      0.000      10.262      10.337
# cylinders[8 cylinders]                         10.5253      0.020    537.498      0.000      10.487      10.564
# cylinders[other]                               10.2105      0.043    236.655      0.000      10.126      10.295
# drive[T.fwd]                                   -0.2543      0.005    -52.105      0.000      -0.264      -0.245
# drive[T.rwd]                                   -0.1202      0.005    -24.239      0.000      -0.130      -0.110
# fuel[T.electric]                               -0.4969      0.065     -7.645      0.000      -0.624      -0.370
# fuel[T.gas]                                    -0.5325      0.007    -81.429      0.000      -0.545      -0.520
# fuel[T.hybrid]                                 -0.4429      0.014    -32.009      0.000      -0.470      -0.416
# fuel[T.other]                                  -0.5123      0.013    -38.112      0.000      -0.539      -0.486
# manufacturer[T.alfa-romeo]                      0.0832      0.129      0.647      0.518      -0.169       0.335
# manufacturer[T.audi]                           -0.0632      0.019     -3.378      0.001      -0.100      -0.027
# manufacturer[T.bmw]                            -0.0910      0.016     -5.632      0.000      -0.123      -0.059
# scale(odometer):C(cylinders)[T.5 cylinders]     0.1028      0.038      2.710      0.007       0.028       0.177
# scale(odometer):C(cylinders)[T.6 cylinders]     0.1877      0.030      6.210      0.000       0.128       0.247
# scale(odometer):C(cylinders)[T.8 cylinders]     0.1703      0.030      5.641      0.000       0.111       0.230
# scale(odometer):C(cylinders)[T.other]           0.3289      0.058      5.693      0.000       0.216       0.442
# scale(year)                                     0.1785      0.029      6.256      0.000       0.123       0.234
# scale(year):C(cylinders)[T.3 cylinders]         0.0694      0.127      0.546      0.585      -0.180       0.318
# scale(year):C(cylinders)[T.4 cylinders]         0.1539      0.029      5.347      0.000       0.097       0.210
# scale(year):C(cylinders)[T.5 cylinders]         0.1666      0.037      4.444      0.000       0.093       0.240
# scale(year):C(cylinders)[T.6 cylinders]         0.2146      0.029      7.478      0.000       0.158       0.271
# scale(year):C(cylinders)[T.8 cylinders]         0.1074      0.029      3.742      0.000       0.051       0.164
# scale(year):C(cylinders)[T.other]               0.1789      0.058      3.086      0.002       0.065       0.293
# ==============================================================================
# Omnibus:                     2417.291   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12084.799
# Skew:                          -0.059   Prob(JB):                         0.00
# Kurtosis:                       5.844   Cond. No.                         284.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### k-fold  검증

# %%
kf = KFold(10, shuffle=True, random_state=0)
model_2_cross_val_score = []
for X_train_index, X_test_index in kf.split(train_data):
    
    X_train= train_data.iloc[X_train_index]
    X_test = train_data.iloc[X_test_index]
    
    X_train = pd.concat([X_train, df[df.index.isin([element for array in for_train_data_train for element in array])]], axis=0)
    X_test = pd.concat([X_test, df[df.index.isin([element for array in for_train_data_test for element in array])]], axis=0)
    model2 = sm.OLS.from_formula("np.log(price) ~ scale(odometer) + scale(year) + scale(odometer): C(cylinders)+ scale(year):C(cylinders) + {}".format("+".join(df.columns.difference(['price','odometer','year'])))+"+0",X_train)
    
    result = model2.fit()
    pred = result.predict(X_test)
    
    model_2_cross_val_score.append(r2_score(np.log(X_test.price),pred))
model_2_cross_val_score
# Out:
# [0.8567531555773513,
#  0.8665178175080448,
#  0.8701910963962949,
#  0.8570896677172747,
#  0.8534153448500201,
#  0.8576719976145297,
#  0.8577060857267403,
#  0.8590974686928134,
#  0.8652366854926187,
#  0.8605948842355206]

# %% [markdown]
# # k-fold 검증 성능 비교
# - 과최적화를 막기 위한 방안

# %%
fig, ax = plt.subplots(figsize=(15,8))

ax.boxplot([model_0_cross_val_score, model_1_cross_val_score, model_2_cross_val_score], sym="b*", labels=['Model 0', 'Model 1', 'Model 2'],)
plt.ylim(0.845,0.88)
plt.title('모델별 검증 비교')
plt.show()

# %%
# condition 미포함
fig, ax = plt.subplots(figsize=(15,8))

ax.boxplot([model_0_cross_val_score, model_1_cross_val_score, model_2_cross_val_score], sym="b*", labels=['Model 0', 'Model 1', 'Model 2'],)
plt.ylim(0.845,0.88)
plt.title('Model1 과 Model2 의 K-fold 검증 비교 condition 미포함')
plt.show()

# %% [markdown]
# # 각 모델별 Test 데이터로 예측한 R-sqaure

# %%
X = train_data[train_data.columns.difference(['price'])]
Y = train_data['price']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .20,random_state=7)

test_df = pd.concat([Y_train,X_train],axis=1)


model1 = sm.OLS.from_formula("np.log(price) ~ scale(odometer) + scale(year) +{}".format("+".join(test_df.columns.difference(['price','odometer','year'])))+"+0",test_df)
result = model1.fit()



prediction = result.predict(test_data[test_data.columns.difference(['price'])])
print("Model 1 R-sqaure : ", r2_score(np.log(test_data['price']),prediction))
# Out:
# Model 1 R-sqaure :  0.8524446827089647

# %%
X = train_data[train_data.columns.difference(['price'])]
Y = train_data['price']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .20,random_state=7)

test_df = pd.concat([Y_train,X_train],axis=1)


model1 = sm.OLS.from_formula("np.log(price) ~ scale(odometer) + scale(year) + scale(odometer): C(cylinders)+ scale(year):C(cylinders)+ scale(odometer): C(fuel) + scale(year):C(fuel) + scale(odometer): C(drive) + scale(year):C(drive) +{}".format("+".join(df.columns.difference(['price','odometer','year'])))+"+0", test_df)

result = model1.fit()
prediction = result.predict(test_data[test_data.columns.difference(['price'])])
print("Model 2 R-sqaure : ", r2_score(np.log(test_data['price']),prediction))
# Out:
# Model 2 R-sqaure :  0.862933988056871

# %% [markdown]
# # model3

# %%
X = train_data[train_data.columns.difference(['price'])]
Y = train_data['price']


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .20,random_state=0)

test_df = pd.concat([Y_train,X_train],axis=1)

model3 = sm.OLS.from_formula("np.log(price**1.0003) ~ scale(odometer) + scale(year) + scale(odometer): C(cylinders)+ scale(year):C(cylinders)+ scale(odometer): C(fuel) + scale(year):C(fuel) + scale(odometer): C(drive) + scale(year):C(drive) + {}".format("+".join(df.columns.difference(['price','odometer','year'])))+"+0", test_df)


result = model3.fit()
pred = result.predict(X_test)

print("R2 score : ",r2_score(np.log(Y_test),pred))
print(result.summary())
# Out:
# R2 score :  0.8675738559714091
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     np.log(price ** 1.0003)   R-squared:                       0.868
# Model:                                 OLS   Adj. R-squared:                  0.867
# Method:                      Least Squares   F-statistic:                     1530.
# Date:                     Mon, 06 Apr 2020   Prob (F-statistic):               0.00
# Time:                             18:14:38   Log-Likelihood:                -883.77
# No. Observations:                    35792   AIC:                             2076.
# Df Residuals:                        35638   BIC:                             3382.
# Df Model:                              153
# Covariance Type:                 nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# cylinders[10 cylinders]                        10.6510      0.041    258.104      0.000      10.570      10.732
# cylinders[3 cylinders]                          9.8710      0.087    113.170      0.000       9.700      10.042
# cylinders[4 cylinders]                         10.0326      0.019    523.044      0.000       9.995      10.070
# cylinders[5 cylinders]                         10.1092      0.029    345.569      0.000      10.052      10.167
# cylinders[6 cylinders]                         10.2488      0.019    544.801      0.000      10.212      10.286
# cylinders[8 cylinders]                         10.4753      0.019    547.006      0.000      10.438      10.513
# cylinders[other]                               10.1180      0.042    239.438      0.000      10.035      10.201
# drive[T.fwd]                                   -0.2509      0.005    -52.559      0.000      -0.260      -0.242
# drive[T.rwd]                                   -0.1265      0.005    -26.031      0.000      -0.136      -0.117
# fuel[T.electric]                               -0.4027      0.074     -5.458      0.000      -0.547      -0.258
# fuel[T.gas]                                    -0.4778      0.007    -72.390      0.000      -0.491      -0.465
# fuel[T.hybrid]                                 -0.3948      0.014    -28.652      0.000      -0.422      -0.368
# fuel[T.other]                                  -0.4597      0.014    -32.052      0.000      -0.488      -0.432
# manufacturer[T.alfa-romeo]                      0.2831      0.125      2.260      0.024       0.038       0.529
# manufacturer[T.audi]                           -0.0410      0.018     -2.248      0.025      -0.077      -0.005
# manufacturer[T.bmw]                            -0.0906      0.016     -5.752      0.000      -0.121      -0.060
# manufacturer[T.buick]                          -0.1881      0.018    -10.406      0.000      -0.224      -0.153
# manufacturer[T.cadillac]                       -0.1112      0.017     -6.386      0.000      -0.145      -0.077
# manufacturer[T.chevrolet]                      -0.2312      0.014    -16.248      0.000      -0.259      -0.203
# manufacturer[T.chrysler]                       -0.3300      0.017    -19.701      0.000      -0.363      -0.297
# manufacturer[T.dodge]                          -0.3492      0.015    -22.672      0.000      -0.379      -0.319
# manufacturer[T.fiat]                           -0.6119      0.032    -19.399      0.000      -0.674      -0.550
# manufacturer[T.ford]                           -0.2613      0.014    -18.456      0.000      -0.289      -0.234
# manufacturer[T.gmc]                            -0.1648      0.015    -10.739      0.000      -0.195      -0.135
# scale(odometer):C(fuel)[T.hybrid]              -0.1469      0.017     -8.750      0.000      -0.180      -0.114
# scale(odometer):C(fuel)[T.other]               -0.0810      0.017     -4.704      0.000      -0.115      -0.047
# scale(odometer):C(drive)[T.fwd]                -0.0134      0.005     -2.571      0.010      -0.024      -0.003
# scale(odometer):C(drive)[T.rwd]                -0.0882      0.005    -17.424      0.000      -0.098      -0.078
# scale(year)                                     0.1686      0.029      5.875      0.000       0.112       0.225
# scale(year):C(cylinders)[T.3 cylinders]        -0.0153      0.124     -0.124      0.901      -0.258       0.227
# scale(year):C(cylinders)[T.4 cylinders]         0.0971      0.028      3.436      0.001       0.042       0.152
# scale(year):C(cylinders)[T.5 cylinders]         0.1126      0.037      3.073      0.002       0.041       0.184
# scale(year):C(cylinders)[T.6 cylinders]         0.1762      0.028      6.284      0.000       0.121       0.231
# scale(year):C(cylinders)[T.8 cylinders]         0.1027      0.028      3.670      0.000       0.048       0.158
# scale(year):C(cylinders)[T.other]               0.0543      0.059      0.925      0.355      -0.061       0.169
# scale(year):C(fuel)[T.electric]                 0.4099      0.164      2.503      0.012       0.089       0.731
# scale(year):C(fuel)[T.gas]                      0.0550      0.007      7.361      0.000       0.040       0.070
# scale(year):C(fuel)[T.hybrid]                   0.0909      0.021      4.255      0.000       0.049       0.133
# scale(year):C(fuel)[T.other]                    0.0524      0.022      2.410      0.016       0.010       0.095
# scale(year):C(drive)[T.fwd]                     0.0244      0.005      4.746      0.000       0.014       0.034
# scale(year):C(drive)[T.rwd]                    -0.0793      0.005    -16.704      0.000      -0.089      -0.070
# ==============================================================================
# Omnibus:                     2341.395   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11048.732
# Skew:                          -0.093   Prob(JB):                         0.00
# Kurtosis:                       5.715   Cond. No.                         377.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
kf = KFold(10, shuffle=True, random_state=0)
model_3_cross_val_score = []
for X_train_index, X_test_index in kf.split(train_data):
    
    X_train= train_data.iloc[X_train_index]
    X_test = train_data.iloc[X_test_index]
    
    X_train = pd.concat([X_train, df[df.index.isin([element for array in for_train_data_train for element in array])]], axis=0)
    X_test = pd.concat([X_test, df[df.index.isin([element for array in for_train_data_test for element in array])]], axis=0)
    model3 = sm.OLS.from_formula("np.log(price**1.001) ~ scale(odometer) + scale(year) + scale(odometer): C(cylinders)+ scale(year):C(cylinders)+ scale(odometer): C(fuel) + scale(year):C(fuel) + scale(odometer): C(drive) + scale(year):C(drive) + {}".format("+".join(df.columns.difference(['price','odometer','year'])))+"+0", X_train)
    result = model.fit()
    pred = result.predict(X_test)
    model_3_cross_val_score.append(r2_score(np.log(X_test.price),pred))
model_3_cross_val_score
# Out:
# [0.8537660513430076,
#  0.8637124244986182,
#  0.8674713098307407,
#  0.8532881314797414,
#  0.8501982981887767,
#  0.8554652883578178,
#  0.8540752657662621,
#  0.8566766965182059,
#  0.8637270560207589,
#  0.8556645069331151]

# %%
fig, ax = plt.subplots(figsize=(15,8))

ax.boxplot([model_0_cross_val_score, model_1_cross_val_score, model_2_cross_val_score ], sym="b*", labels=['Model 1', 'Model 2', 'Model 3'],)
plt.ylim(0.845,0.88)
plt.title('Model1 과 Model2 의 K-fold 검증 비교')
plt.show()

# %% [markdown]
# # 향후 프로젝트 진행 방향
# - 변수간 상관관계 심층 분석
# - 모델별 성능 평가
# - 가설 증명

# %% [markdown]
# ## 해결하지 못한 의문점
# - 데이터 분할, 카테고리 변수
#   - **Train-Test split**, **K-fold**
#   - 부트스트래핑?
# - ANOVA
#   - 카테고리 독립변수간의 상관관계 분석 방식에 대한 의문

# %% [markdown]
# # VIF Factor ???

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(
    dfX.values, i) for i in range(dfX.shape[1])]
vif["features"] = dfX.columns
vif = vif.sort_values("VIF Factor").reset_index(drop=True)
vif
# Out:
#      VIF Factor                 features
# 0          1.00  title_status_parts only
# 1          1.00     title_status_missing
# 2          1.01     manufacturer_ferrari
# 3          1.01  manufacturer_land rover
# 4          1.01                 type_bus
# ..          ...                      ...
# 128       20.72        manufacturer_ford
# 129      170.87    cylinders_8 cylinders
# 130      222.92    cylinders_4 cylinders
# 131      241.85    cylinders_6 cylinders
# 132      852.60                     year
#
# [133 rows x 2 columns]

# %%
vif.sort_values(by=['VIF Factor'], ascending=False).iloc[:20]
# Out:
#      VIF Factor                features
# 132      852.60                    year
# 131      241.85   cylinders_6 cylinders
# 130      222.92   cylinders_4 cylinders
# 129      170.87   cylinders_8 cylinders
# 128       20.72       manufacturer_ford
# 127       19.97                fuel_gas
# 126       17.27  manufacturer_chevrolet
# 125       11.01     manufacturer_toyota
# 124        7.50                state_ca
# 123        7.31       manufacturer_jeep
# 122        7.25     manufacturer_nissan
# 121        7.23        manufacturer_ram
# 120        7.23      manufacturer_honda
# 119        6.13        manufacturer_gmc
# 118        5.34      manufacturer_dodge
# 117        5.04   cylinders_5 cylinders
# 116        5.02                 mileage
# 115        4.69                state_fl
# 114        4.67               drive_fwd
# 113        4.52                state_tx

# %%
test2.columns
# Out:
# Index(['price', 'year', 'odometer', 'drive', 'fuel', 'manufacturer', 'state',
#        'title_status', 'transmission', 'type', 'paint_color', 'cylinders'],
#       dtype='object')

# %%
from statsmodels.graphics.api import interaction_plot, abline_plot

plt.figure(figsize=(10,8))
fig = interaction_plot(df['paint_color'], df['transmission'], np.log(df['price']), ms=10, ax=plt.gca())

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig = df.boxplot('price', 'fuel', ax=ax, grid=False)

# %%
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols

rehab_lm = ols('price ~ C(fuel)', data=test2).fit()
table9 = anova_lm(rehab_lm)
print(table9)

print(rehab_lm.model.data.orig_exog)
# Out:
#                df           sum_sq        mean_sq       F  PR(>F)
# C(fuel)      4.00  364697340480.33 91174335120.08 1053.23    0.00
# Residual 42561.00 3684347198815.98    86566274.26     nan     nan
#        Intercept  C(fuel)[T.electric]  C(fuel)[T.gas]  C(fuel)[T.hybrid]  \
# 0           1.00                 0.00            1.00               0.00
# 3           1.00                 0.00            1.00               0.00
# 10          1.00                 0.00            1.00               0.00
# 11          1.00                 0.00            1.00               0.00
# 12          1.00                 0.00            1.00               0.00
# ...          ...                  ...             ...                ...
# 77637       1.00                 0.00            1.00               0.00
# 77639       1.00                 0.00            1.00               0.00
# 77641       1.00                 0.00            1.00               0.00
# 77642       1.00                 0.00            1.00               0.00
# 77643       1.00                 0.00            1.00               0.00
#
#        C(fuel)[T.other]
# 0                  0.00
# 3                  0.00
# 10                 0.00
# 11                 0.00
# 12                 0.00
# ...                 ...
# 77637              0.00
# 77639              0.00
# 77641              0.00
# 77642              0.00
# 77643              0.00
#
# [42566 rows x 5 columns]

# %%
rehab_lm = ols('price ~ C(cylinders)', data=test2).fit()
table9 = anova_lm(rehab_lm)
print(table9)

print(rehab_lm.model.data.orig_exog)
# Out:
#                    df           sum_sq        mean_sq      F  PR(>F)
# C(cylinders)     7.00  546047963143.79 78006851877.68 947.71    0.00
# Residual     42558.00 3502996576152.51    82311118.38    nan     nan
#        Intercept  C(cylinders)[T.12 cylinders]  C(cylinders)[T.3 cylinders]  \
# 0           1.00                          0.00                         0.00
# 3           1.00                          0.00                         0.00
# 10          1.00                          0.00                         0.00
# 11          1.00                          0.00                         0.00
# 12          1.00                          0.00                         0.00
# ...          ...                           ...                          ...
# 77637       1.00                          0.00                         0.00
# 77639       1.00                          0.00                         0.00
# 77641       1.00                          0.00                         0.00
# 77642       1.00                          0.00                         0.00
# 77643       1.00                          0.00                         0.00
#
#        C(cylinders)[T.4 cylinders]  C(cylinders)[T.5 cylinders]  \
# 0                             1.00                         0.00
# 3                             0.00                         0.00
# 10                            1.00                         0.00
# 11                            1.00                         0.00
# 12                            1.00                         0.00
# ...                            ...                          ...
# 77637                         0.00                         0.00
# 77639                         0.00                         0.00
# 77641                         1.00                         0.00
# 77642                         0.00                         0.00
# 77643                         1.00                         0.00
#
#        C(cylinders)[T.6 cylinders]  C(cylinders)[T.8 cylinders]  \
# 0                             0.00                         0.00
# 3                             0.00                         1.00
# 10                            0.00                         0.00
# 11                            0.00                         0.00
# 12                            0.00                         0.00
# ...                            ...                          ...
# 77637                         0.00                         1.00
# 77639                         1.00                         0.00
# 77641                         0.00                         0.00
# 77642                         1.00                         0.00
# 77643                         0.00                         0.00
#
#        C(cylinders)[T.other]
# 0                       0.00
# 3                       0.00
# 10                      0.00
# 11                      0.00
# 12                      0.00
# ...                      ...
# 77637                   0.00
# 77639                   0.00
# 77641                   0.00
# 77642                   0.00
# 77643                   0.00
#
# [42566 rows x 8 columns]

# %% [markdown]
# # 변수간 상관관계

# %% [markdown]
# # 모델별 성능 평가

# %% [markdown]
# # 가설 증명

# %% [markdown]
# # 데이터 한번에 불러오는 함수

# %%
def get_data_by_sigma(num):
    global test2
    test2 = test[(test['price'] >= (test['average'] - (test['stdev'] * num)))
                 & (test['price'] <= (test['average'] +
                                      (test['stdev'] * num)))]

    test2 = test2[test2['mileage'] == test2['odometer']]

    test2['year'] = test2['year'].apply(lambda x: 2019 if x < 1980 else x)

    test2 = test2[test2['odometer'] != 0]

    test2 = test2[test2['price'] != 0]

    test2 = test2[[
        'price', 'year', 'odometer', 'drive', 'fuel', 'manufacturer', 'state',
        'title_status', 'transmission', 'type', 'paint_color', 'cylinders'
    ]]
    print("{} sigma data : ".format(num), test2.shape)

# %%
# 더미 변수화 하면서 오류 발생 시키는 카테고리 값들 수정하기
for column in test2.columns.difference(['price','mileage','year']):
    test2[column] = test2[column].apply(lambda x : x.replace("-","").replace(" ","") if "-" or " " in x else x)
test2['cylinders'] = test2['cylinders'].str.get(0)
